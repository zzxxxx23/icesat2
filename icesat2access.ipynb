# %%
#导入包
import icepyx as ipx
import os
import shutil                                                                                                                                                                                                        # import geopandas as gpd
# %matplotlib inline
import socket
import time

# %%
# time.sleep(10)

# %%
#使用所需的搜索参数创建 ICESat-2 数据对象
short_name = 'ATL13'
spatial_extent = [102.00, 24.00,103.00, 24.97]
date_range = ['2019-01-01','2019-12-31']
#使用我们的输入创建数据对象
region_a = ipx.Query(short_name, spatial_extent, date_range)
print(region_a.product)
print(region_a.product_version)
region_a.visualize_spatial_extent()
# Out:
# ATL13
# 006

# %%
#使用我们的输入创建数据对象
region_a = ipx.Query(short_name, spatial_extent, date_range)
print(region_a.product)
print(region_a.product_version)
region_a.visualize_spatial_extent()
# Out:
# ATL13
# 006

# %%
#查询数据产品
region_a.CMRparams
region_a.avail_granules()
# Out:
# {'Number of available granules': 47,
#  'Average size of granules (MB)': 88.34190871867727,
#  'Total size of all granules (MB)': 4152.069709777832}

# %%
#登录NASA 地球数据
earthdata_uid = 'zz_xxxx'
# password="Zhp20010102@"
email = '23zz.xxxx@gmail.com'

# %%
#压缩下载大小的颗粒计数
print(region_a.reqparams)
# Out:
# {'page_size': 2000}

# %%
#子集化
region_a.subsetparams()
# Out:
# {'time': '2019-01-01T00:00:00,2019-12-31T23:59:59',
#  'bbox': '102.0,24.0,103.0,24.97'}

# %%
#下订单
region_a.order_granules()
region_a.granules.orderIDs
# Out:
# Total number of data order requests is  1  for  47  granules.
# Data request  1  of  1  is submitting to NSIDC
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# File f:\miniconda\miniconda3\py311\Lib\site-packages\urllib3\connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
# ...

# %%
#下载
path = 'E:\icesat2_data\icesat2\py\ppp'
region_a.download_granules(path)
# Out:
# Beginning download of zipped output...
